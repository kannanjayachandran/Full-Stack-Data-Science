# %% [markdown]
# <h1 align="center" style="color: orange"> Pandas II </h1>

# %%
import pandas as pd

# %%
df = pd.read_csv('.\Data\penguins_size.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\kanna\AppData\Local\Temp\ipykernel_1160\2252002246.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('.\Data\penguins_size.csv')

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
print(df.columns)

df.keys()
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=344, step=1)

# %%
df.values
# Out:
# array([['Adelie', 'Torgersen', 39.1, ..., 181.0, 3750.0, 'MALE'],
#        ['Adelie', 'Torgersen', 39.5, ..., 186.0, 3800.0, 'FEMALE'],
#        ['Adelie', 'Torgersen', 40.3, ..., 195.0, 3250.0, 'FEMALE'],
#        ...,
#        ['Gentoo', 'Biscoe', 50.4, ..., 222.0, 5750.0, 'MALE'],
#        ['Gentoo', 'Biscoe', 45.2, ..., 212.0, 5200.0, 'FEMALE'],
#        ['Gentoo', 'Biscoe', 49.9, ..., 213.0, 5400.0, 'MALE']],
#       dtype=object)

# %%
df.dtypes
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
islands = df.groupby('island')
islands

# %%
islands['body_mass_g'].mean()
# Out:
# island
# Biscoe       4716.017964
# Dream        3712.903226
# Torgersen    3706.372549
# Name: body_mass_g, dtype: float64

# %%
torgersen = islands.get_group('Torgersen')
torgersen.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
print(f"Maximum body mass per island:\n{islands['body_mass_g'].max()}\n\n")
print(f"Minimum body mass per island:\n{islands['body_mass_g'].min()}\n\n")  
print(f"Mean body mass per island:\n{islands['body_mass_g'].mean()}\n\n")  
print(islands['body_mass_g'].describe())
# Out:
# Maximum body mass per island:
# island
# Biscoe       6300.0
# Dream        4800.0
# Torgersen    4700.0
# Name: body_mass_g, dtype: float64
#
#
# Minimum body mass per island:
# island
# Biscoe       2850.0
# Dream        2700.0
# Torgersen    2900.0
# Name: body_mass_g, dtype: float64
#
#
# Mean body mass per island:
# island
# Biscoe       4716.017964
# Dream        3712.903226
# Torgersen    3706.372549
# Name: body_mass_g, dtype: float64
#
#
#            count         mean         std     min     25%     50%      75%  \
# island
# Biscoe     167.0  4716.017964  782.855743  2850.0  4200.0  4775.0  5325.00
# Dream      124.0  3712.903226  416.644112  2700.0  3400.0  3687.5  3956.25
# Torgersen   51.0  3706.372549  445.107940  2900.0  3337.5  3700.0  4000.00
#
#               max
# island
# Biscoe     6300.0
# Dream      4800.0
# Torgersen  4700.0

# %%
islands.plot(kind='box', y='body_mass_g')
# Out:
# island
# Biscoe       Axes(0.125,0.11;0.775x0.77)
# Dream        Axes(0.125,0.11;0.775x0.77)
# Torgersen    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
islands.boxplot(vert=False)
# Out:
# Biscoe            Axes(0.1,0.559091;0.363636x0.340909)
# Dream        Axes(0.536364,0.559091;0.363636x0.340909)
# Torgersen             Axes(0.1,0.15;0.363636x0.340909)
# dtype: object

# %%
df.plot(kind='scatter', x='body_mass_g', y='flipper_length_mm')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
islands.plot.area(x='culmen_depth_mm', y='flipper_length_mm', stacked=False)
# Out:
# island
# Biscoe       Axes(0.125,0.11;0.775x0.77)
# Dream        Axes(0.125,0.11;0.775x0.77)
# Torgersen    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df.plot.area(x='culmen_depth_mm', y='flipper_length_mm', stacked=False)
# Out:
# <Axes: xlabel='culmen_depth_mm'>

# %%
pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(18, 9), diagonal="kde")
# Out:
# array([[<Axes: xlabel='culmen_length_mm', ylabel='culmen_length_mm'>,
#         <Axes: xlabel='culmen_depth_mm', ylabel='culmen_length_mm'>,
#         <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>,
#         <Axes: xlabel='body_mass_g', ylabel='culmen_length_mm'>],
#        [<Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>,
#         <Axes: xlabel='culmen_depth_mm', ylabel='culmen_depth_mm'>,
#         <Axes: xlabel='flipper_length_mm', ylabel='culmen_depth_mm'>,
#         <Axes: xlabel='body_mass_g', ylabel='culmen_depth_mm'>],
#        [<Axes: xlabel='culmen_length_mm', ylabel='flipper_length_mm'>,
#         <Axes: xlabel='culmen_depth_mm', ylabel='flipper_length_mm'>,
#         <Axes: xlabel='flipper_length_mm', ylabel='flipper_length_mm'>,
#         <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>],
#        [<Axes: xlabel='culmen_length_mm', ylabel='body_mass_g'>,
#         <Axes: xlabel='culmen_depth_mm', ylabel='body_mass_g'>,
# ...
